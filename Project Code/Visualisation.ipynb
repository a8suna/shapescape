# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/carlodemello/activations/activations.pt

# %%
import pandas as pd
import torch

# %%
data = torch.load("/kaggle/input/datasets/carlodemello/activations/activations.pt")

# %%
conv_0_Conv2d = data["conv_0_Conv2d"]
conv_1_BatchNorm2d = data["conv_1_BatchNorm2d"]
conv_2_ReLU = data["conv_2_ReLU"]
conv_3_MaxPool2d = data["conv_3_MaxPool2d"]

conv_4_Conv2d = data["conv_4_Conv2d"]
conv_5_BatchNorm2d = data["conv_5_BatchNorm2d"]
conv_6_ReLU = data["conv_6_ReLU"]
conv_7_MaxPool2d = data["conv_7_MaxPool2d"]

conv_8_Conv2d = data["conv_8_Conv2d"]
conv_9_BatchNorm2d = data["conv_9_BatchNorm2d"]
conv_10_ReLU = data["conv_10_ReLU"]
conv_11_MaxPool2d = data["conv_11_MaxPool2d"]

classifier_0_Flatten = data["classifier_0_Flatten"]
classifier_1_Linear = data["classifier_1_Linear"]
classifier_2_ReLU = data["classifier_2_ReLU"]
classifier_3_Dropout = data["classifier_3_Dropout"]

classifier_4_Linear = data["classifier_4_Linear"]
classifier_5_ReLU = data["classifier_5_ReLU"]
classifier_6_Dropout = data["classifier_6_Dropout"]
classifier_7_Linear = data["classifier_7_Linear"]

# %%
import matplotlib.pyplot as plt

feature_map = conv_10_ReLU[0][30].detach().cpu()

plt.imshow(feature_map)
plt.title("Feature Map3")
plt.colorbar()

plt.savefig("feature_map3.png", dpi=300, bbox_inches='tight')  #saves plot
plt.show()

# %%
conv_8_Conv2d[0][30].size()
# Out:
# torch.Size([8, 8])

# %%
import matplotlib.pyplot as plt

feature_map1 =conv_10_ReLU[0][30].detach().cpu()



plt.imshow(feature_map1)
plt.title("Feature Map")
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

feature_map1 =conv_0_Conv2d[0][30].detach().cpu()
# Do it for number 30 for everything 
#thats fine

plt.imshow(feature_map)
plt.title("Feature Map")
plt.colorbar()
plt.show()

# %%
conv_0_Conv2d[0][30]
conv_2_ReLU[0][30]
# Out:
# tensor([[0.0000, 0.7323, 0.7323,  ..., 0.7323, 0.7323, 2.2779],
#         [0.0000, 0.3602, 0.3602,  ..., 0.3602, 0.3602, 1.2380],
#         [0.0000, 0.3602, 0.3602,  ..., 0.3602, 0.3602, 1.2380],
#         ...,
#         [0.0000, 0.3602, 0.3602,  ..., 0.3602, 0.3602, 1.2380],
#         [0.0000, 0.3602, 0.3602,  ..., 0.3602, 0.3602, 1.2380],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]])
